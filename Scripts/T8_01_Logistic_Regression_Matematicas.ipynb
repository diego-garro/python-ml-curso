# %% [markdown]
# # Las matemáticas tras la regresión logística
#
# ## Las tablas de contingencia

# %%
import pandas as pd

# %%
df = pd.read_csv("/home/diego/Documentos/Developer/Python/Scripts/MachineLearning/Curso_JG_Gomila/datasets/gender-purchase/Gender Purchase.csv")
df.head()
# Out:
#    Gender Purchase
# 0  Female      Yes
# 1  Female      Yes
# 2  Female       No
# 3    Male       No
# 4    Male      Yes

# %%
df.shape
# Out:
# (511, 2)

# %%
contingency_table = pd.crosstab(df["Gender"], df["Purchase"])
contingency_table
# Out:
# Purchase   No  Yes
# Gender
# Female    106  159
# Male      125  121

# %%
contingency_table.sum(axis=1)
# Out:
# Gender
# Female    265
# Male      246
# dtype: int64

# %%
contingency_table.sum(axis=0)
# Out:
# Purchase
# No     231
# Yes    280
# dtype: int64

# %%
contingency_table.astype("float").div(contingency_table.sum(axis=1), axis=0)
# Out:
# Purchase       No      Yes
# Gender
# Female    0.40000  0.60000
# Male      0.50813  0.49187

# %% [markdown]
# ## La probabilidad condicional

# %%
from IPython.display import display, Math, Latex

# %% [markdown]
# * ¿Cuál es la probabilidad de que un cliente compre un producto sabiendo que es un hombre?
# * ¿Cuál es la probabilidad de que sabiendo que un cliente compra un producto, sea mujer?

# %%
display(Math(r'P(Purchase|Male) = \frac{Numero\ total\ de\ compras\ hechas\ por\ hombres}{Numero\ total\ de\ hombres\ por\ grupo} = \frac{Purchase\cap Male}{Male}'))
121/246
# Out:
# $\displaystyle P(Purchase|Male) = \frac{Numero\ total\ de\ compras\ hechas\ por\ hombres}{Numero\ total\ de\ hombres\ por\ grupo} = \frac{Purchase\cap Male}{Male}$
# 0.491869918699187

# %%
display(Math(r'P(No\ Purchase|Male) = 1 - P(Purchase|Male)'))
125/246
# Out:
# $\displaystyle P(No\ Purchase|Male) = 1 - P(Purchase|Male)$
# 0.508130081300813

# %%
display(Math(r'P(Female|Purchase) = \frac{Numero\ total\ de\ compras\ hechas\ por\ mujeres}{Numero\ total\ de\ \ compras} = \frac{Female\cap Purchase}{Purchase}'))
159/280
# Out:
# $\displaystyle P(Female|Purchase) = \frac{Numero\ total\ de\ compras\ hechas\ por\ mujeres}{Numero\ total\ de\ \ compras} = \frac{Female\cap Purchase}{Purchase}$
# 0.5678571428571428

# %%
display(Math(r'P(Male|Purchase)'))
121/280
# Out:
# $\displaystyle P(Male|Purchase)$
# 0.43214285714285716

# %%
display(Math(r'P(Puchase|Male)'))
print(121/246)
display(Math(r'P(No\ Puchase|Male)'))
print(125/246)
display(Math(r'P(Puchase|Female)'))
print(159/265)
display(Math(r'P(No\ Puchase|Female)'))
print(106/265)
# Out:
# $\displaystyle P(Puchase|Male)$
# 0.491869918699187
# 0.508130081300813
# 0.6
# 0.4
# $\displaystyle P(No\ Puchase|Male)$
# $\displaystyle P(Puchase|Female)$
# $\displaystyle P(No\ Puchase|Female)$

# %% [markdown]
# ## Cociente o ratio de probabilidades
